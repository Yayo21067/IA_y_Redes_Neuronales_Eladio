# %%
print("Eladio Juvera Gonzalez \n ID:2114783 IMC \n Grupo:008")
# Out:
# Eladio Juvera Gonzalez
#  ID:2114783 IMC
#  Grupo:008

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/mpg.csv")

# %%
print("Primeras 5 filas")
print(df.head(5))
print("\nTipos de datos")
print(df.dtypes)
# Out:
# Primeras 5 filas
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino
#
# Tipos de datos
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# ...

# %%
print("Valores Nulos ")
print(df.isnull().sum())
# Out:
# Valores Nulos
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
print("Valores Nulos ")
print(df.isnull().sum())
mediana_hp = df['horsepower'].median()
df['horsepower'] = df['horsepower'].fillna(mediana_hp)
df['relacion_peso_potencia'] = df['weight'] / df['horsepower']
print(df.head(5))
# Out:
# Valores Nulos
# mpg                       0
# cylinders                 0
# displacement              0
# horsepower                0
# weight                    0
# acceleration              0
# model_year                0
# origin                    0
# name                      0
# relacion_peso_potencia    0
# dtype: int64
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name  relacion_peso_potencia
# 0          70    usa  chevrolet chevelle malibu               26.953846
# 1          70    usa          buick skylark 320               22.381818
# ...

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['acceleration'], bins=30, color='orange', edgecolor='black', alpha=0.7)
plt.title('Distribución de la Aceleración')
plt.xlabel('Aceleración (m/s²)')
plt.ylabel('Cantidad de Vehículos')
plt.grid(axis='y',alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['displacement'], df['horsepower'], alpha=0.5, color='darkorange')
plt.title('Desplazamiento del Motor vs Caballos de Fuerza')
plt.xlabel('Desplazamiento del Motor')
plt.ylabel('Caballos de Fuerza')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
resumen_origen = df.groupby('origin')['mpg'].mean()
resumen_origen.plot(kind='bar',color=['blue', 'red', 'green'] )
plt.title('Rendimiento Promedio (MPG) por Origen')
plt.xlabel('País de Origen')
plt.ylabel('Promedio de Millas por Galón')
plt.xticks(rotation=0)
plt.show()
